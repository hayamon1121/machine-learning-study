# %% [markdown]
# ## 練習12-1

# %% [markdown]
# ロジスティック回帰では、各正解データに分類される確率を計算するため、確率の和は１になるはずである。A,B,Cの確率の和が1.1となってしまっているのが矛盾している。

# %% [markdown]
# ## 練習12-2

# %% [markdown]
# 1 4

# %% [markdown]
# ## 練習12-3

# %% [markdown]
# 予測結果の平均値をとる。

# %% [markdown]
# ## 練習12-4

# %% [markdown]
# 2 3
