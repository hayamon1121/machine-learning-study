# %% [markdown]
# ### 練習8-1

# %% [markdown]
# 1,3,4

# %% [markdown]
# ### 練習8-2

# %% [markdown]
# 1,2

# %% [markdown]
# ### 練習8-3

# %%
import pandas as pd
Acol = pd.Series([2,3,5])
Bcol = pd.Series([7,4,1])
Acol * Bcol
# Out:
# 0    14
# 1    12
# 2     5
# dtype: int64
