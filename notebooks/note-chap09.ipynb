# %% [markdown]
# 2026-02-03
#
# # 学習内容
# ### 書籍/教材:スッキリわかるPythonによる機械学習入門
# ### 範囲: 第9章 教師あり学習の総合演習
# ### 目的: 総合演習で今までの内容を振り返る。
#
#  -----------------------------
# ## <関数まとめ>
#
#
#
#  -----------------------------
# ## <内容まとめ>
# １．目的の明確化
# ２．データ収集
# ３．ダミー変数化
# ４，テストデータの分離
# ５．前処理
# ・欠損値処理（行削除・全体代表値埋め・グループ代表値埋め）
# 「・外れ値の除外
# ｜・特徴量の絞り込み
# ｜・標準化
# L・多項式特徴量、交互作用特徴量の追加
# ・特徴量xと正解tに分割
# ・教師データの分割
# ６．学習
# ・未学習状態モデルの生成(分類→決定木、回帰→線形回帰)
# ・訓練データで学習(不均衡テータ補正)
# ７．評価
# ・検証データで評価し指標確認（分類→正解率、回帰→決定係数）
# 　→NG：前処理にもどる
# 　→OK：テストデータで評価
#
#
#
#
#
#  -----------------------------
# ## まとめ
#
#
#
# --------------------------------------
# ## 以下は実装例
